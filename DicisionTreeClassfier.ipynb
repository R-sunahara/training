# %%
#決定木を利用し、irisデータのあやめ品種がどの品種に分類されるかのモデルを構築する
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
iris = pd.read_csv('iris.csv')

# %%
#決定木の構築
from sklearn import tree

# %%
X = iris[["sepal.length", "sepal.width", "petal.length", "petal.width"]]
Y = iris[["variety"]]

# %%
treeClf = tree.DecisionTreeClassifier(max_depth=2)
treeClf.fit(X,Y)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=2, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
#決定木の可視化

# %%
with open("tree.dot", 'w') as f:
    f = tree.export_graphviz(treeClf, out_file=f, feature_names=["sepal.length", "sepal.width", "petal.length", "petal.width"])

# %%
#ローカルに保存し、コマンドプロンプトで以下コードを実行するとpngに変換できる
#cd C:\Users\komar\Downloads
#dir (該当フォルダがあることを確認)
#dot -Tpng tree.doc -o tree.png

# %%
#jupyter上で完結させたかったが、Docker仮想環境のLibrary/bin内にGrapvizをインストールしたり色々したが、
#[GraphViz's executables not found] のエラーを消せなかった
#よほど不便にならない限り、決定木のdocファイルはcmdで直接変換しよう。
#いつか解決するといいけど、、

# %%
from IPython.display import Image

# %%
#cmdでpngに変換後、また作業ディレクトリにアップロードして表示するという遠回りな方法
Image("tree.png")
